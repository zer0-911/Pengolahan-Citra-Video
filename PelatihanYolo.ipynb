# %% [markdown]
# # **Deep Learning Untuk Visikomputer**
# ## Deteksi Obyek Menggunakan Yolo

# %% [markdown]
# # 1. Pendahuluan
# Lihat Modul Bab 1
# #  2. Convolutional Neural Network
# Lihat Modul Bab 2
# # 3. Deteksi Obyek Menggunakan Yolo
# Lihat Modul Bab 3

# %% [markdown]
# # 4. YoloV5
# ## 4.1. ultralystic YoloV5
#
# YOLOv5  adalah keluarga dari arsitektur objek deteksi  dengan model yang telah di training pada data set COCO. YOLOV5 ini dikembangkan berdasar riset open-source dari Ultralytics dengan repostory dapat didownload melalui link :
# 	[https://github.com/ultralytics/yolov5](https://github.com/ultralytics/yolov5)

# %% [markdown]
# ## 4.2. Lisensi
#
# ultralytics\/yolov5 dibawah lisensi *GNU General Public License v3.0*
#
# Berdasar lisensi ini maka kontributor dapat  mendistribusikan program dan  modifikasi dengan ketentuan bahwa segala modifikasi dan penggunaan progam ini harus menggunakan lisensi yang sama.

# %% [markdown]
# ## 4.3. Varian Yolov5
#
# Model	|size(pixels)|	mAPval 0.5:0.95	|mAPval 0.5	|SpeedCPU b(ms)|Speed V100 b1(ms) |	Speed V100 b32 (ms) |	params (M)|	 FLOPs @640 (B)
# ------|---|-----|----------|-----------|-------|---------|----------|---
# YOLOv5n|	640	|28.0|	45.7	|45	|6.3	|0.6	|1.9	|4.5
# YOLOv5s	|640	|37.4|	56.8|	98|	6.4|	0.9	|7.2	|16.5
# YOLOv5m|	640|	45.4	|64.1|	224|	8.2|	1.7	|21.2|	49.0
# YOLOv5l|	640	|49.0	|67.3	|430	|10.1|	2.7|	46.5|	109.1
# YOLOv5x|	640 |	50.7	|68.9	|766	|12.1|	4.8|	86.7|	205.7
# YOLOv5n6|	1280	|36.0|	54.4|	153	|8.1	|2.1	|3.2	|4.6
# YOLOv5s6|	1280|	44.8	|63.7	|385	|8.2	|3.6	|12.6	|16.8
# YOLOv5m6|	1280|	51.3	|69.3	|887|	11.1|	6.8|	35.7|	50.0
# YOLOv5l6|	1280|	53.7	|71.3	|1784|	15.8|	10.5|	76.8|	111.4

# %% [markdown]
# ## 4.4. Instalasi YoloV5
# ### 4.4.1. Menginstal Dependecies melalui Github
#
# YoloV5 Bekerja pada lingkungan Python>=3.8  dan PyTorch>=1.7 serta beberapa dependecies sebagi berikut :
#
#   1. Base
#     * matplotlib>=3.2.2
#     * numpy>=1.18.5
#     * opencv-python>=4.1.1
#     * Pillow>=7.1.2
#     * PyYAML>=5.3.1
#     * requests>=2.23.0
#     * scipy>=1.4.1  # Google Colab version
#     * torch>=1.7.0
#     * torchvision>=0.8.1
#     * tqdm>=4.41.0
#   2. Logging
#     * tensorboard>=2.4.1
#   3. Plotting
#     * pandas>=1.1.4
#     * seaborn>=0.11.0
#
#   Daftar library tersebut disimpan dalam file dengan nama
# *requirements.txt*

# %%
	#Listing 4.1.
# !pip install -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt

# %% [markdown]
# ### 4.4.2. Menyiapkan direktori pada google drive

# %%
#Listing 4.2.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 4.4.3. Masuk ke Direktori yang disediakan oleh Google Drive

# %%
#Listing 4.3. 
# %cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %% [markdown]
# ### 4.4.4. Install yolov5 dari repositori pada github

# %%
#Listing 4.4. 
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %% [markdown]
# ### 4.4.5. Masuk Ke direktori yolov5

# %%
#Listing 4.5.
# %cd yolov5
# Out:
# /content/drive/MyDrive/yolov5

# %% [markdown]
# ### 4.4.6. Menguji apakah  yolov5 sudah terinstall dengan baik.
#
# Selanjutnya kita melakukan inference secara langsung pada contoh citra untuk deteksi objek. Misalkan kita akan melakukan objek deteksi pada citra zidane.jpg yang terletak pada floder data/images

# %%
#Listing 4.6
import torch
import utils
display = utils.notebook_init()  # checks
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# YOLOv5 🚀 v6.1-174-gc4cb7c6 torch 1.11.0+cu113 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.4/107.7 GB disk)
# detect: weights=['yolov5s.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-174-gc4cb7c6 torch 1.11.0+cu113 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 /content/drive/MyDrive/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, Done. (0.280s)
# image 2/2 /content/drive/MyDrive/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, Done. (0.214s)
# Speed: 2.5ms pre-process, 247.0ms inference, 5.3ms NMS per image at shape (1, 3, 640, 640)
# ...

# %% [markdown]
# ### 4.4.7. Ringkasan Listing 4.1. sampai 4.6
#
#
#
#
# ```
# #Listing 4.1.
# !pip install -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt
#
# #Listing 4.2.
# from google.colab import drive
# drive.mount('/content/drive')
#
# #Listing 4.3.
# %cd drive/MyDrive
#
# #Listing 4.4.
# !git clone https://github.com/ultralytics/yolov5
#
# #Listing 4.5.
# %cd yolov5
#
# #Listing 4.5.
# %cd yolov5
#
# #Listing 4.6
# import torch
# import utils
# display = utils.notebook_init()  # checks
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# ```

# %% [markdown]
# # 5. Implementasi Deteksi Obyek Dengan YoloV5
# ## 5.1. Data set coco
#
# COCO adalah dataset deteksi objek, segmentasi, dan teks berskala besar. COCO memiliki beberapa fitur:
#
# * Object segmentation
# *   Recognition in context
# * Superpixel stuff segmentation
# * 330K images (>200K labeled)
# * 1.5 million object instances
# * 80 object categories
# * 91 stuff categories
# * 5 captions per image
# * 250,000 people with keypoints
# <img src="https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEizZ8U4fS5rmxDiiv1BqALsjvfJBAEWwazIqxhHVaWwd5oW_vE9BS3O3uiu-mzfS5_sBdA9P22hEL4NzsJPbNhTP4YLCqR3ioWW19jEGzCW3dP7VH_iRvpjOtDVVA3LxNHdYJg1AooGUq9-dEjepskWlreH1Jnzp6IIKAnebbY68UQG-Mh4eg/s1172/DataSetCoco.png"/>
#
# | ID | OBJECT (PAPER) |  OBJECT (2014 REL.) | OBJECT (2017 REL.) | SUPER CATEGORY |
# |:--:|:--------------:|:-------------------:|:------------------:|:--------------:|
# | 0  | person         | person              | person             | person         |
# | 1  | bicycle        | bicycle             | bicycle            | vehicle        |
# | 2  | car            | car                 | car                | vehicle        |
# | 3  | motorcycle     | motorcycle          | motorcycle         | vehicle        |
# | 4  | airplane       | airplane            | airplane           | vehicle        |
# | 5  | bus            | bus                 | bus                | vehicle        |
# | 6  | train          | train               | train              | vehicle        |
# | 7  | truck          | truck               | truck              | vehicle        |
# | 8  | boat           | boat                | boat               | vehicle        |
# | 9  | traffic light  | traffic light       | traffic light      | outdoor        |
# | 10 | fire hydrant   | fire hydrant        | fire hydrant       | outdoor        |
# | 11 | street sign    | -                   | -                  | outdoor        |
# | 12 | stop sign      | stop sign stop sign | outdoor            |                |
# | 13 | parking meter  | parking meter       | parking meter      | outdoor        |
# | 14 | bench          | bench               | bench              | outdoor        |
# | 15 | bird           | bird                | bird               | animal         |
# | 16 | cat            | cat                 | cat                | animal         |
# | 17 | dog            | dog                 | dog                | animal         |
# | 18 | horse          | horse               | horse              | animal         |
# | 19 | sheep          | sheep               | sheep              | animal         |
# | 20 | cow            | cow                 | cow                | animal         |
# | 21 | elephant       | elephant            | elephant           | animal         |
# | 22 | bear           | bear                | bear               | animal         |
# | 23 | zebra          | zebra               | zebra              | animal         |
# | 24 | giraffe        | giraffe             | giraffe            | animal         |
# | 25 | hat            | -                   | -                  | accessory      |
# | 26 | backpack       | backpack            | backpack           | accessory      |
# | 27 | umbrella       | umbrella            | umbrella           | accessory      |
# | 28 | shoe           | -                   | -                  | accessory      |
# | 29 | eye            | glasses             | -                  | -              |
# | 30 | handbag        | handbag             | handbag            | accessory      |
# | 31 | tie            | tie                 | tie                | accessory      |
# | 32 | suitcase       | suitcase            | suitcase           | accessory      |
# | 33 | frisbee        | frisbee             | frisbee            | sports         |
# | 34 | skis           | skis                | skis               | sports         |
# | 35 | snowboard      | snowboard           | snowboard          | sports         |
# | 36 | sports ball    | sports ball         | sports ball        | sports         |
# | 37 | kite           | kite                | kite               | sports         |
# | 38 | baseball bat   | baseball bat        | baseball bat       | sports         |
# | 39 | baseball glove | baseball glove      | baseball glove     | sports         |
# | 40 | skateboard     | skateboard          | skateboard         | sports         |
# | 41 | surfboard      | surfboard           | surfboard          | sports         |
# | 42 | tennis racket  | tennis racket       | tennis racket      | sports         |
# | 43 | bottle         | bottle              | bottle             | kitchen        |
# | 44 | plate          | -                   | -                  | kitchen        |
# | 45 | wine glass     | wine glass          | wine glass         | kitchen        |
# | 46 | cup            | cup                 | cup                | kitchen        |
# | 47 | fork           | fork                | fork               | kitchen        |
# | 48 | knife          | knife               | knife              | kitchen        |
# | 49 | spoon          | spoon               | spoon              | kitchen        |
# | 50 | bowl           | bowl                | bowl               | kitchen        |
# | 51 | banana         | banana              | banana             | food           |
# | 52 | apple          | apple               | apple              | food           |
# | 53 | sandwich       | sandwich            | sandwich           | food           |
# | 54 | orange         | orange              | orange             | food           |
# | 55 | broccoli       | broccoli            | broccoli           | food           |
# | 56 | carrot         | carrot              | carrot             | food           |
# | 57 | hot dog        | hot dog             | hot dog            | food           |
# | 58 | pizza          | pizza               | pizza              | food           |
# | 59 | donut          | donut               | donut              | food           |
# | 60 | cake           | cake                | cake               | food           |
# | 61 | chair          | chair               | chair              | furniture      |
# | 62 | couch          | couch               | couch              | furniture      |
# | 63 | potted plant   | potted plant        | potted plant       | furniture      |
# | 64 | bed            | bed                 | bed                | furniture      |
# | 65 | mirror         | -                   | -                  | furniture      |
# | 66 | dining table   | dining table        | dining table       | furniture      |
# | 67 | window         | -                   | -                  | furniture      |
# | 68 | desk           | -                   | -                  | furniture      |
# | 69 | toilet         | toilet              | toilet             | furniture      |
# | 70 | door           | -                   | -                  | furniture      |
# | 71 | tv             | tv                  | tv                 | electronic     |
# | 72 | laptop         | laptop              | laptop             | electronic     |
# | 73 | mouse          | mouse               |                    | mouse          |
# | 74 | remote         | remote              | remote             | electronic     |
# | 75 | keyboard       | keyboard            | keyboard           | electronic     |
# | 76 | cell phone     | cell phone          | cell phone         | electronic     |
# | 77 | microwave      | microwave           | microwave          | appliance      |
# | 78 | oven           | oven                | oven               | appliance      |
# | 79 | toaster        | toaster             | toaster            | appliance      |
# | 80 | sink           | sink                | sink               | appliance      |
# | 81 | refrigerator   | refrigerator        | refrigerator       | appliance      |
# | 82 | blender        | -                   | -                  | appliance      |
# | 83 | book           | book                | book               | indoor         |
# | 84 | clock          | clock               | clock              | indoor         |
# | 85 | vase           | vase                | vase               | indoor         |
# | 86 | scissors       | scissors            | scissors           | indoor         |
# | 87 | teddy bear     | teddy bear          | teddy bear         | indoor         |
# | 88 | hair drier     | hair drier          | hair drier         | indoor         |
# | 89 | toothbrush     | toothbrush          | toothbrush         | indoor         |
# | 91 | hair brush     | -                   | -                  | indoor         |

# %% [markdown]
# ## 5.2. Torch Hub
#
#
#  Torch Hub : *Application Programmable Interface (API)* untuk mengiteraksikan dua buah program atau lebih untuk  publikasi model yang telah dilatih untuk membantu berbagi penelitian dan meningkatkan produktifitas.
#
#  Contoh : Memuat Model yolov5s dari yolov5 repositori github menggunakan torch hub

# %%
#Listing 5.1. 
import torch
# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
print(model)

# %% [markdown]
# ## 5.3. Deteksi YoloV5 dengan *pretrained Model Yolov5s*
# Selanjutnya kita akan melakukan deteksi menggunakan model yolov5s.
#
# Dalam contoh ini kita akan melakukan deteksi kendaraan pada gambar
#
# <img src="https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEjIEtVl4_8StKx2oK9XgIBXUeLQ66fWuPFvTcp5LuFCmj8zkojpUug-rS3qLK_JG8WESks9cBUMFDDv9_CxW3qTGlF2M7ogmz6sCT3FOhrUnafLxDAsZZLdgXMTE4rbb-EAVI9wpilqxOyFghoJdIrnOnqwSgfjIX_1yHY0Ww3Bt0-AriYVVQ/s400/LaluLintas.jpg">

# %% [markdown]
# Terlebih dahulu mari kita download diatas terlebih dahulu.

# %%
# Listing 5.2. : Download Gambar Lalulintas.jpg 
# !git clone https://github.com/ekomulyanto/DataSet
# Out:
# Cloning into 'DataSet'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 27 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (27/27), done.

# %% [markdown]
# ### 5.3.1. Deteksi Obyek  menggunakan  *pretrained yolov5 model* dengan menampilkan Daftar Bounding Box dan Kelas

# %%
#Listing 5.3. 
import torch
import cv2

from google.colab.patches import cv2_imshow
# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', _verbose=False)
# Inference
results = model('/content/DataSet/LaluLintas.jpg')
results.render()
cv2_imshow(results.imgs[0])
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# <PIL.Image.Image image mode=RGB size=854x540 at 0x7F3B89290DD0>

# %% [markdown]
# ### 5.3.2. Deteksi Obyek  menggunakan  *pretrained yolov5 model* dengan menampilkan Daftar Bounding Box dan Kelas

# %%
#Listing 5.4. 
import torch
# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Image
# Inference
results = model('/content/DataSet/LaluLintas.jpg') 
print(results)
for res in results.pandas().xyxy:
  Detected =res.values.tolist()
  for xmin,ymin,xmax,ymax,confidence,cl,name  in Detected:
    print( xmin,ymin,xmax,ymax,confidence,cl,name)
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# image 1/1: 540x854 8 persons, 20 cars, 3 motorcycles
# Speed: 16.6ms pre-process, 242.8ms inference, 1.5ms NMS per image at shape (1, 3, 416, 640)
#
# 172.3622589111328 386.5364990234375 321.822021484375 534.7117919921875 0.8004635572433472 2 car
# 449.7451477050781 357.9072265625 597.4844360351562 529.6392822265625 0.7732093334197998 2 car
# 50.306243896484375 435.2798156738281 203.7943878173828 539.2158813476562 0.7691829800605774 2 car
# 685.1732177734375 401.8829345703125 822.009033203125 536.9957275390625 0.6933510303497314 2 car
# 220.374267578125 343.71881103515625 352.7753601074219 461.9937438964844 0.6856034994125366 2 car
# 617.6670532226562 437.368896484375 766.505615234375 537.53955078125 0.6684039235115051 2 car
# 70.47112274169922 324.5973205566406 209.274658203125 435.83380126953125 0.6662769913673401 2 car
# ...

# %% [markdown]
# ### 5.3.3. Seting Parameter YoloV5
# Selanjutnya tidak semua kelas dalam data set coco akan kita gunakan semua.
#
# Contoh :  deteksi  mobil
#
# Parameter :
# 1.   confidence score =0.1
# 2.   Class model =[2] (Id Untuk Kendaraan Jenis mobil = 2)

# %%
#Listing 5.5.
import torch
from google.colab.patches import cv2_imshow

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', _verbose=False)
#  Deteksi Mobil : Kelas =2
model.classes=[2]
model.conf =0.1
# Inference
results = model('/content/DataSet/LaluLintas.jpg') 
#Render Bounding box ke citra.
results.render()
cv2_imshow(results.imgs[0])
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# <PIL.Image.Image image mode=RGB size=854x540 at 0x7F3B85048190>

# %% [markdown]
# ## 5.4. Deteksi Obyek Pada Video
# ### 5.4.1. Deteksi Kendaraan Di Jalan Tol Versi Google Colab

# %%
#Listing  5.6. 
import cv2 
import torch
import numpy as np 
from IPython.display import clear_output
from time import sleep
from google.colab.patches import cv2_imshow

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', _verbose=False)
fn="/content/DataSet/RoadTrafic.mp4"
cap = cv2.VideoCapture(fn)
if (cap.isOpened()== False): 
  print("Error opening video stream or file")

# Membaca video sampai selesai
n=0
while(cap.isOpened()):
  #Dalam contoh ini video di baca sampai dengan frame ke 20
  n=n+1 
  if n>20:
    break
  # Capture frame-by-frame
  ret, frame = cap.read()
  if ret == True:
    results = model(frame)
    #Render Boundingbox dan kelas ke frame
    results.render()
    print("frame : ",n)
    cv2_imshow(results.imgs[0])
    sleep(1)
    clear_output(wait=True)
# Out:
# frame :  20
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F3B84F61AD0>

# %% [markdown]
# ### 5.4.2. Deteksi Kendaraan Di Jalan Tol Versi Komputer Dekstop
# Di bawah ini adalah contoh program yang terapkan pada Komputer lokal.

# %%
#Listing 5.7. 
import cv2 
import torch
import numpy as np 


# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', _verbose=False)
fn="..\\..\\DataSetPelatihanV5\\RoadTrafic.mp4"
cap = cv2.VideoCapture(fn)
if (cap.isOpened()== False): 
  print("Error opening video stream or file")

# Baca sam pai selesai
while(cap.isOpened()):
  # Capture frame-by-frame
  ret, frame = cap.read()
  if ret == True:
    results = model(frame)
    results.render()
    cv2.imshow('Frame',results.imgs[0])
    # Tekan Tombol Q Untuk Keluar
    if cv2.waitKey(25) & 0xFF == ord('q'):
      break

  # Keluar dari loop
  else: 
    break
cap.release()
# Hapus Semua frame
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Deteksi Obyek Pada  Dataset Custom
# Selanjutnya akan diberikan contoh deteksi obyek menggunakan Dataset Custom. Dataset tersebut akan menggunekan  yolovs sebagai model.
#
# 1. Model->yoloV5s
# 2. Data

# %% [markdown]
# ## 6.1. Dataset
# <img src="https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEi03Gw8p7FpmROCKJbjR55_fg5l34_9farh9TYzUMAvwq5eQxHJieBl4AwsRfnOzoT1dZnsE3NwTZxDmiu8TmmCp4nGA0zy1MrYEbQizZ9qSWUk5VIjMCLPtBOyj-yVqRa2wqIXZVY1gP0VyNuXrrqklU8ML7Zt-NO-ivipSqvzAMrsMmGBYA/s400/TrainingCustomData1.png" width="1000">

# %% [markdown]
# ## 6.2. Pelabelan Dataset
#
# Agar dataset tersebut dapat digunakan, maka data set tersebut harus diberi label sesuai dengan kelas yang telah didefinisikan.
# Untuk pemberian label pada dataset dapat dilakukan secara oline menggunakan program Roboflow.
#
# [Roboflow](https://roboflow.com/)

# %% [markdown]
# ## 6.3. Download Custom Dataset
# Setelah Dataset diberi label selanjutnya data set di download.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="pqlLb6aGpIWJDwEKyDTB")
project = rf.workspace("pelatihan-yolo").project("pelatihan-yolo")
dataset = project.version(1).download("yolov5")

# %% [markdown]
# Hasil download akan menghasilkan direktori baru dengan nama *Pelatihan-Yolo-1*  yang berisi
# 1. Direktori Tes
# 2. Direktori  Train
# 3. Direktori Valid
# 4. file  data.yaml
#
# <img src="https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEiTfblTvtX5rCX8ef-37UKrfi622_thXq8nxYQtBR6HuJxho0x8dHW_-UN01idLUMxOdwLZ_TnVoaPGnTVqQszzmmZmZSQ1QxGMjDn5FXeGaqcnpBrn5OSpmIcvIoEHNAiu4Ed6d8oo--ncI69JZol2wrPx01P63FJ2_7IurwYdkMChPKp-aA/s320/gb2.JPG" width="300">
#
# File *data.yaml* berisi konfigurasi dataset yang terdiri
# 1. Daftar  nama kelas
# 2. Direktori  dataset training
# 3. Direktori daset untuk validasi.
#
# file *data.yaml*
# ```
# names:
# - gelas
# - termos
# nc: 2
# train: Pelatihan-Yolo-1/train/images
# val: Pelatihan-Yolo-1/valid/images
#
# ```

# %% [markdown]
# ## 6.4.  Membuat model custom yolov5sCustom
# Selanjutnya kita akan melakukan pelatihan dataset        dengan menggunakan model
#
# 1.  File *models/yolov5s.yaml* `
#
# yolov5s merupakan pretrained model dataset COCO128 dengan jumlah kelas 80.
# Oleh karena model kita terdiri dari dua kelas maka jumlah kelas pada file yolov5s.yaml harus diganti menjadi 2
#
# File *models/yolov5s.yaml*
#
# ```
# # YOLOv5 🚀 by Ultralytics, GPL-3.0 license
#
# # Parameters
# nc: 80  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]
# ```

# %% [markdown]
# ### 6.4.2. Copy file *models/yolov5s.yaml* ke *models/yolov5sCustom.yaml*

# %%
# %cp models/yolov5s.yaml models/yolov5sCustom.yaml
# Out:
# cp: cannot stat 'models/yolov5s.yaml': No such file or directory

# %% [markdown]
# ### 6.4.3.. Edit Jumlah kelas pada file  yolov5sCustom.yaml
# Selanjutnya jumlah kelas pada
#
# File *models/yolov5sCustom.yaml*
#
# ```
# # YOLOv5 🚀 by Ultralytics, GPL-3.0 license
#
# # Parameters
# nc: 2  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]
# ```

# %%
# !dir
# Out:
# Pelatihan-Yolo-1  sample_data

# %% [markdown]
# https://pytorch.org/hub/ultralytics_yolov5/
#
# https://docs.ultralytics.com/tutorials/pytorch-hub/
#
# https://www.section.io/engineering-education/
#
# https://object-detection-with-yolov5-and-pytorch/
